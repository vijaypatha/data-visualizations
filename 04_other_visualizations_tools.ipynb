# %% [markdown]
# # Introduction to Seaborn
#
# What is Seaborn?
# Seaborn is a powerful Python data visualization library built on top of Matplotlib. It provides a high-level interface for creating attractive and informative statistical graphics.
#
# Seaborn is often chosen over Matplotlib because it simplifies complex visualizations and provides better aesthetics by default. Here are the key reasons why Seaborn is preferred in many cases:
#
# 1. Simplicity & Less Code
# 2. Better Default Aesthetics
# 3. Built-in Statistical Features
# 4. Handles Categorical Data Easily
# 5. Easy Multi-Plot Grids
#
# When to Use Matplotlib Instead of Seaborn?
#
# 👉 Use Matplotlib if:
# 	•	You need low-level customization (Seaborn is built on Matplotlib, but Matplotlib gives more control).
# 	•	You are creating highly specialized or non-standard plots.
# 	•	You are combining different plot types in one figure.
#
# 👉 Use Seaborn if:
# 	•	You want cleaner, more attractive visuals with less code.
# 	•	You are analyzing Pandas DataFrames.
# 	•	You need quick statistical insights (e.g., KDE, pair plots).

# %% [markdown]
# ## 0. Loading Library and Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Set the style
sns.set_style("whitegrid")

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sakshigoyal7/credit-card-customers")

print("Path to dataset files:", path)

# Load the dataset into a pandas DataFrame
df = pd.read_csv(path + "/BankChurners.csv")  

# Display the first few rows of the dataset
print(df.head(3))
# Out:
# ...
# Path to dataset files: /Users/vijaypatha/.cache/kagglehub/datasets/sakshigoyal7/credit-card-customers/versions/1
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# 1              44  ...        8256.0                  864           7392.0
# 2              36  ...        3418.0                    0           3418.0
#
# ...

# %% [markdown]
# ## 1. Basic Plots: Scatter Plot, Box Plot, Histogram, Line Plot

# %% [markdown]
# ### A. Scatter Plot

# %%
# Create a scatter plot
sns.scatterplot(x="Credit_Limit", y="Total_Revolving_Bal", data=df)
plt.title("Credit Limit vs Revolving Balance")
plt.show()

# %% [markdown]
# ### B. Box Plot

# %%
sns.boxplot(x="Credit_Limit", y="Income_Category", data=df)
plt.title("Distribution of Credit Limit by Income_Category")
plt.show()

# %%
all_numerical_features = df.select_dtypes(include=["number"]).columns
print(all_numerical_features)
# Out:
# Index(['CLIENTNUM', 'Customer_Age', 'Dependent_count', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
key_numerical_features = ['Customer_Age', 'Dependent_count', 'Months_on_book',
       'Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio']
for feature in key_numerical_features:
    sns.boxplot(x='Attrition_Flag', y=feature, data=df, palette="viridis")

    plt.title(f'{feature} by Attrition Flag')
    plt.show()
# Out:
# /var/folders/tn/bllk4s_n0k9g75m59d6nyp8w0000gn/T/ipykernel_33770/357200097.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Attrition_Flag', y=feature, data=df, palette="viridis")
# /var/folders/tn/bllk4s_n0k9g75m59d6nyp8w0000gn/T/ipykernel_33770/357200097.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Attrition_Flag', y=feature, data=df, palette="viridis")
# /var/folders/tn/bllk4s_n0k9g75m59d6nyp8w0000gn/T/ipykernel_33770/357200097.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# ### C. Histogram

# %%
sns.histplot(x="Credit_Limit",data=df, bins=10, color='skyblue', edgecolor='black')
plt.title("Distribution of Credit Limit", fontsize=14, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Distribution of Credit Limit')

# %%
sns.displot(data=df, x="Credit_Limit", kind="hist", bins=10)

# %% [markdown]
# ### D. Line Plot

# %%
sns.lineplot(x="Customer_Age",y="Credit_Limit", data=df)
plt.title("Distribution of Credit Limit by Customer Age", fontsize=14, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Distribution of Credit Limit by Customer Age')

# %% [markdown]
# ### E. Bar Plots

# %%
sns.barplot(x="Income_Category", y="Credit_Limit", data=df, palette="rocket")
plt.title(" Credit Limit by Income Category")
plt.xlabel("Income Category")
plt.ylabel(" Credit Limit")
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/tn/bllk4s_n0k9g75m59d6nyp8w0000gn/T/ipykernel_33770/3730452708.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Income_Category", y="Credit_Limit", data=df, palette="rocket")

# %% [markdown]
# #### E. 1 Bar Graph with Grouping
#
# - In the given grouped bar plot, the data is being grouped in two ways:
#
#     - Primary grouping: By "Income_Category" (x-axis)
#
#     - Secondary grouping: By "Gender" (hue parameter)
#
# The bars are grouped first by Income_Category, and within each category, they are further divided by Gende

# %%
sns.barplot(x="Income_Category", y="Credit_Limit", hue="Gender", data=df, palette="viridis")
plt.title("Credit Limit by Income Category and Gender")
plt.xlabel("Income Category")
plt.ylabel("Average Credit Limit")
plt.xticks(rotation=45)
plt.legend(title="Gender")
plt.show()

# %%
sns.barplot(y="Income_Category", x="Credit_Limit", data=df, ci="sd")
# Out:
# /var/folders/tn/bllk4s_n0k9g75m59d6nyp8w0000gn/T/ipykernel_33770/3241423923.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(y="Income_Category", x="Credit_Limit", data=df, ci="sd")
# <Axes: xlabel='Credit_Limit', ylabel='Income_Category'>

# %% [markdown]
# ## 2. Distribution Plots

# %% [markdown]
# ### A. Kernel Density Estimation (KDE) Plots

# %%
sns.displot(data=df, x="Credit_Limit", kind="kde")

# %% [markdown]
# ### B. Empirical Cumulative Distribution Function (ECDF) Plots

# %%
sns.displot(data=df, x="Credit_Limit", kind="ecdf")

# %% [markdown]
# ### C. Regression Plots
# Regression plots visualize linear relationships between variables:

# %%
sns.regplot(data=df, x="Credit_Limit", y="Avg_Utilization_Ratio")
# Out:
# <Axes: xlabel='Credit_Limit', ylabel='Avg_Utilization_Ratio'>

# %%
sns.residplot(data=df, x="Credit_Limit", y="Avg_Utilization_Ratio")
# Out:
# <Axes: xlabel='Credit_Limit', ylabel='Avg_Utilization_Ratio'>
